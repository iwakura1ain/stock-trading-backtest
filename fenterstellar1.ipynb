# %%
import finterstellar as fst

# %%
df = fst.get_price("AMZN")
df.plot()
df
# Out:
# Symbols      AMZN
# Date
# 2021-11-08 174.45
# 2021-11-09 178.81
# 2021-11-10 174.10
# 2021-11-11 173.62
# 2021-11-12 176.26
# ...           ...
# 2022-11-01  96.79
# 2022-11-02  92.12
# 2022-11-03  89.30
# 2022-11-04  90.98
# 2022-11-07  90.53
#
# [252 rows x 1 columns]
